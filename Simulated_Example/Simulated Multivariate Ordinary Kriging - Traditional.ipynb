# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Data" data-toc-modified-id="Import-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Data</a></span><ul class="toc-item"><li><span><a href="#Map-the-Data" data-toc-modified-id="Map-the-Data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Map the Data</a></span></li><li><span><a href="#Check-the-Distribution-and-Correlation-of-the-Data" data-toc-modified-id="Check-the-Distribution-and-Correlation-of-the-Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Check the Distribution and Correlation of the Data</a></span></li></ul></li><li><span><a href="#Correlograms" data-toc-modified-id="Correlograms-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Correlograms</a></span><ul class="toc-item"><li><span><a href="#Initialize-Correlogram-Types" data-toc-modified-id="Initialize-Correlogram-Types-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Initialize Correlogram Types</a></span></li><li><span><a href="#Fit-Experimental-Correlogram-Points" data-toc-modified-id="Fit-Experimental-Correlogram-Points-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Fit Experimental Correlogram Points</a></span></li><li><span><a href="#Calculate-Rotation-Matrix" data-toc-modified-id="Calculate-Rotation-Matrix-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Calculate Rotation Matrix</a></span></li><li><span><a href="#Primary-Correlogram" data-toc-modified-id="Primary-Correlogram-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Primary Correlogram</a></span></li><li><span><a href="#Secondary-Correlogram" data-toc-modified-id="Secondary-Correlogram-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Secondary Correlogram</a></span></li><li><span><a href="#Scaling-Correlogram" data-toc-modified-id="Scaling-Correlogram-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Scaling Correlogram</a></span></li><li><span><a href="#C_Z-Correlogram-MM2" data-toc-modified-id="C_Z-Correlogram-MM2-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>C_Z Correlogram MM2</a></span></li><li><span><a href="#Plots-Correlogram-Models" data-toc-modified-id="Plots-Correlogram-Models-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Plots Correlogram Models</a></span></li><li><span><a href="#Cross-Correlogram" data-toc-modified-id="Cross-Correlogram-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Cross Correlogram</a></span></li><li><span><a href="#LMC" data-toc-modified-id="LMC-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>LMC</a></span><ul class="toc-item"><li><span><a href="#Primary" data-toc-modified-id="Primary-2.10.1"><span class="toc-item-num">2.10.1&nbsp;&nbsp;</span>Primary</a></span></li><li><span><a href="#Secondary" data-toc-modified-id="Secondary-2.10.2"><span class="toc-item-num">2.10.2&nbsp;&nbsp;</span>Secondary</a></span></li><li><span><a href="#Cross" data-toc-modified-id="Cross-2.10.3"><span class="toc-item-num">2.10.3&nbsp;&nbsp;</span>Cross</a></span></li><li><span><a href="#Plot-LMC" data-toc-modified-id="Plot-LMC-2.10.4"><span class="toc-item-num">2.10.4&nbsp;&nbsp;</span>Plot LMC</a></span></li></ul></li></ul></li><li><span><a href="#Kriging" data-toc-modified-id="Kriging-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Kriging</a></span><ul class="toc-item"><li><span><a href="#Data-Statistics" data-toc-modified-id="Data-Statistics-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Data Statistics</a></span></li><li><span><a href="#Create-a-KDTree-to-Quickly-Get-Nearest-Points" data-toc-modified-id="Create-a-KDTree-to-Quickly-Get-Nearest-Points-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create a KDTree to Quickly Get Nearest Points</a></span></li><li><span><a href="#Ordinary-Kriging" data-toc-modified-id="Ordinary-Kriging-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Ordinary Kriging</a></span></li><li><span><a href="#Full-Cokriging" data-toc-modified-id="Full-Cokriging-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Full Cokriging</a></span></li><li><span><a href="#Ordinary-Collocated-Cokriging---MM1" data-toc-modified-id="Ordinary-Collocated-Cokriging---MM1-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Ordinary Collocated Cokriging - MM1</a></span></li><li><span><a href="#Ordinary-Collocated-Cokriging---MM2" data-toc-modified-id="Ordinary-Collocated-Cokriging---MM2-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Ordinary Collocated Cokriging - MM2</a></span></li><li><span><a href="#Intrinsic-Collocated-Cokriging---MM1" data-toc-modified-id="Intrinsic-Collocated-Cokriging---MM1-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Intrinsic Collocated Cokriging - MM1</a></span></li><li><span><a href="#Intrinsic-Collocated-Cokriging---MM2" data-toc-modified-id="Intrinsic-Collocated-Cokriging---MM2-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Intrinsic Collocated Cokriging - MM2</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#Pixelplt" data-toc-modified-id="Pixelplt-3.9.1"><span class="toc-item-num">3.9.1&nbsp;&nbsp;</span>Pixelplt</a></span></li><li><span><a href="#Data-Reproduction" data-toc-modified-id="Data-Reproduction-3.9.2"><span class="toc-item-num">3.9.2&nbsp;&nbsp;</span>Data Reproduction</a></span></li><li><span><a href="#Histogram-Reproduction" data-toc-modified-id="Histogram-Reproduction-3.9.3"><span class="toc-item-num">3.9.3&nbsp;&nbsp;</span>Histogram Reproduction</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# This notebook implements the Geostatistics Lesson . This code is provided for educational purposes and should be reviewed jointly with the lesson <a href="http://www.geostatisticslessons.com/lessons/Collocated_Cokriging">Collocated Cokriging</a>.
#
# Learning Objectives
# - Review simple cokriging.
# - Understand the why the Markov Models where developed.
# - Explore the differences between Markov model <span>&#8544;</span> and Markov model <span>&#8545;</span>.
# - Formulated the Kriging equations using the Markov models.
# - Implement the Markov model <span>&#8544;</span> and Markov model <span>&#8545;</span>.
# - Understand the Markov model <span>&#8544;</span> and Markov model <span>&#8545;</span> work flow(source code available).

# %%
print('Package Versions:')
import matplotlib as matplotlib; print("  matplotlib:", matplotlib.__version__)
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd; print("  pandas:", pd.__version__)
import sys; print("  python:", sys.version_info)
import numpy as np; print("  numpy:", np.__version__)
import sklearn as sklearn; print("  sklearn:", sklearn.__version__)
import os 
import scipy; print("  scipy:", scipy.__version__)
from scipy import stats
from tqdm import tqdm
from scipy.spatial import distance_matrix
from sklearn.metrics import mean_squared_error
np.set_printoptions(precision=3)
# Out:
# Package Versions:
#   matplotlib: 3.1.3
#   pandas: 0.23.0
#   python: sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
#   numpy: 1.16.3
#   sklearn: 0.20.2
#   scipy: 1.1.0

# %% [markdown]
# # Import Data

# %% [markdown]
# Consider two varable Z(\textbf{u}), the primary variable - Grade, and Y(\textbf{u}), the secondary variable - seismic. We have sample for the primary variable Z(\textbf{u}) at 64 locations. The secondary variable Y(\textbf{u}) is measured at all location within our domain. It is considered in a probabilistic sense to use Y(\textbf{u}) to inform the prediction of Z(\textbf{u}).

# %%
datafl = pd.read_csv('Data/Cluster1.out')
datafl_sec = pd.read_csv('Data/Ydata.out')
truth = pd.read_csv('Data/true.out')
x = np.asarray(pd.read_csv('Data/X.out')).reshape(len(datafl_sec))
y = np.asarray(pd.read_csv('Data/Y.out')).reshape(len(datafl_sec))
print(datafl.describe())
print(datafl_sec.describe())
# Out:
#                X          Y    Primary  Secondary
# count  64.000000  64.000000  64.000000  64.000000
# mean   50.000000  50.000000  -0.424719  -0.197425
# std    28.867513  28.867513   1.032475   0.912744
# min     6.250000   6.250000  -2.623800  -2.020500
# 25%    28.125000  28.125000  -1.015100  -0.767850
# 50%    50.000000  50.000000  -0.387650  -0.224450
# 75%    71.875000  71.875000   0.176975   0.254700
# max    93.750000  93.750000   2.148700   1.889200
#                   X             Y     Secondary
# count  10000.000000  10000.000000  10000.000000
# mean      50.000000     50.000000     -0.250033
# std       28.867513     28.867513      0.936804
# min        0.500000      0.500000     -3.272810
# 25%       25.250000     25.250000     -0.817388
# 50%       50.000000     50.000000     -0.183005
# 75%       74.750000     74.750000      0.327832
# max       99.500000     99.500000      2.781670

# %% [markdown]
# ## Map the Data

# %%
vlim = (-3,3)
f, ax = plt.subplots(1,2,figsize=(13,5.5))
XMIN, XMAX = 0, 100
YMIN, YMAX = 0, 100
SMIN, SMAX = -3,3
gridd = pd.DataFrame()
gridd['Y'] = y
gridd['X'] = x
gridd['Estimate'] = datafl_sec['Secondary']
gridded = np.reshape(gridd.sort_values(by=['Y', 'X'], axis=0, ascending=True)['Estimate'].values,
                 [100, 100], order='C',)
img0 = ax[0].scatter(datafl['X'],datafl['Y'], c = datafl['Primary'].values)
ax[0].set_title('Drill Hole Locations',size = 20)
ax[0].set_xlabel('Easting',size = 20)
ax[0].set_ylabel('Northing',size = 20)
ax[0].axis('equal')
ax[0].set(xlim=(0, 100), ylim=(0, 100))
img1 = ax[1].imshow(gridded, origin='lower', extent=[XMIN, XMAX, YMIN, YMAX], aspect='equal',
                interpolation='none', vmin=SMIN, vmax=SMAX, cmap='viridis')
ax[1].set_xlabel('Easting',size = 20)
ax[1].set_ylabel('Northing',size = 20)
ax[1].set_title('Secondary Data',size = 20)
f.colorbar(img0,ax = ax[0])
f.colorbar(img1,ax = ax[1])
plt.tight_layout()
plt.savefig('../0-Figures/Truth',bbox_inches = 'tight',pad_inches = 0)

# %% [markdown]
# ## Check the Distribution and Correlation of the Data

# %%
# Set up the axes with gridspec
corr = np.corrcoef(datafl['Primary'],datafl['Secondary'])[0,1]
vlim= (-3,3)
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.5, wspace=0.5)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(datafl['Primary'], datafl['Secondary'], 'ok', markersize=3)
main_ax.set_xlim(vlim)
main_ax.set_ylim(vlim)
main_ax.set_title('Cross Plot: Primary Vs Secondary Data',size = 15)
main_ax.text(-2.5,2.5,'Corr = {0:.3f}'.format(np.corrcoef(datafl['Primary'],datafl['Secondary'])[0,1]),size=20)

# histogram on the attached axes
x_hist.hist(datafl['Primary'], 40, histtype='stepfilled',label = 'Primary',
            orientation='vertical', color='gray',range=vlim)
x_hist.set_xlabel('Primary Histogram',size = 20)
x_hist.invert_yaxis()
x_hist.text(-3,5,'Mean = {0:.2f}'.format(np.average(datafl['Primary'])),size=10)
x_hist.text(-3,6,'Var = {0:.2f}'.format(1.00),size=10)


y_hist.hist(datafl['Secondary'], 40, histtype='stepfilled',
orientation='horizontal', color='gray',range=vlim)
y_hist.set_ylabel('Secondary Histogram',size = 20)
y_hist.invert_xaxis()
y_hist.text(5,-2.8,'Mean = {0:.2f}'.format(np.average(datafl['Secondary'])),rotation=90,size=10)
y_hist.text(6,-2.8,'Var = {0:.2f}'.format(1.00),rotation=90,size=10)
plt.savefig('../0-Figures/Cross_plt')

# %% [markdown]
# # Correlograms

# %% [markdown]
# ## Initialize Correlogram Types

# %%
def covar ( t, d, r ):
    h = d / r
    if t == 1: #Spherical
        c = 1 - h * (1.5 - 0.5 * np.square(h))
        c[h > 1] = 0
    elif t == 2: #Exponential
        c = np.exp( -3 * h )
    elif t == 3: #Gaussian
        c = np.exp( -3 * np.square(h) )
    return c

# %% [markdown]
# ## Fit Experimental Correlogram Points

# %% [markdown]
# Experimental variogram points where pre calculated.

# %%
varcalcfl_1 = pd.read_csv('2-vargfls/varcalc_Cluster.out')
varcalcfl_2 = pd.read_csv('2-vargfls/varcalc_YDATA.out')
varcalcfl_3 = pd.read_csv('2-vargfls/varcalc_Cross.out')

# %%
ones = np.zeros(shape=(50))
Cross_ones = np.zeros(shape=(50))
H = np.zeros(shape=(50))
for h in range(1,50):
    H[h] = h 

fig, axes = plt.subplots(2,3, figsize=(15,10))
axes[0,0].plot(varcalcfl_1['Lag Distance'][varcalcfl_1['Variogram Index']==1]
               ,1-varcalcfl_1['Variogram Value'][varcalcfl_1['Variogram Index']==1]
               ,'ro',color ='Red')
axes[0,1].plot(varcalcfl_2['Lag Distance'][varcalcfl_2['Variogram Index']==1]
               ,1-varcalcfl_2['Variogram Value'][varcalcfl_2['Variogram Index']==1]
               ,'ro',color ='Green')
axes[0,2].plot(varcalcfl_3['Lag Distance'][varcalcfl_3['Variogram Index']==1]
               ,corr-varcalcfl_3['Variogram Value'][varcalcfl_3['Variogram Index']==1]
               ,'ro',color ='Blue')
axes[0,0].plot(H,ones,color = 'Black')
axes[0,1].plot(H,ones,color = 'Black')
axes[0,2].plot(H,ones,color = 'Black')
axes[0,0].set_xlim(0,50)
axes[0,0].set_ylim(-0.1,1)
axes[0,0].set_ylabel('$\u03C1_{Z}(h)$',size=35)
axes[0,0].set_xlabel('h',size=35)
axes[0,1].set_xlim(0,50)
axes[0,1].set_ylim(-0.1,1)
axes[0,1].set_ylabel('$\u03C1_Y(h)$',size=35)
axes[0,1].set_xlabel('h',size=35)
axes[0,2].set_xlim(0,50)
axes[0,2].set_ylim(-0.1,1)
axes[0,2].set_ylabel('$\u03C1_{ZY}(h)$',size=35)
axes[0,2].set_xlabel('h',size=35)
axes[0,0].set_title('Primary Correlogram Major',size = 20)
axes[0,1].set_title('Secondary Correlogram Major',size = 20)
axes[0,2].set_title('Cross Correlogram Major',size = 20)

axes[1,0].plot(varcalcfl_1['Lag Distance'][varcalcfl_1['Variogram Index']==2]
               ,1-varcalcfl_1['Variogram Value'][varcalcfl_1['Variogram Index']==2]
               ,'ro',color ='Red')
axes[1,1].plot(varcalcfl_2['Lag Distance'][varcalcfl_2['Variogram Index']==2]
               ,1-varcalcfl_2['Variogram Value'][varcalcfl_2['Variogram Index']==2]
               ,'ro',color ='Green')
axes[1,2].plot(varcalcfl_3['Lag Distance'][varcalcfl_3['Variogram Index']==2]
               ,corr-varcalcfl_3['Variogram Value'][varcalcfl_3['Variogram Index']==2]
               ,'ro',color ='Blue')
axes[1,0].plot(H,ones,color = 'Black')
axes[1,1].plot(H,ones,color = 'Black')
axes[1,2].plot(H,ones,color = 'Black')
axes[1,0].set_xlim(0,50)
axes[1,0].set_ylim(-0.1,1)
axes[1,0].set_ylabel('$\u03C1_{Z}(h)$',size=35)
axes[1,0].set_xlabel('h',size=35)
axes[1,1].set_xlim(0,50)
axes[1,1].set_ylim(-0.1,1)
axes[1,1].set_ylabel('$\u03C1_Y(h)$',size=35)
axes[1,1].set_xlabel('h',size=35)
axes[1,2].set_xlim(0,50)
axes[1,2].set_ylim(-0.1,1)
axes[1,2].set_ylabel('$\u03C1_{ZY}(h)$',size=35)
axes[1,2].set_xlabel('h',size=35)
axes[1,0].set_title('Primary Correlogram Minor',size = 20)
axes[1,1].set_title('Secondary Correlogram Minor',size = 20)
axes[1,2].set_title('Cross Correlogram Minor',size = 20)
plt.tight_layout()
#plt.savefig('../0-Figures/True_vargs')

# %% [markdown]
# ## Calculate Rotation Matrix

# %% [markdown]
# Using a major direction of 90 degrees east of north, this is farily obvious from the primary and secondary data.

# %%
def Rot_Mat(Azimuth,a_max,a_min):
    theta = (Azimuth/180.) * np.pi
    Rot_Mat = np.dot(np.array([[1/a_max,0],[0,1/a_min]]),
              np.array([[np.cos(theta),np.sin(theta)],[-np.sin(theta),np.cos(theta)]]))
    return Rot_Mat

# %% [markdown]
# ## Primary Correlogram

# %%
# h1 = Set of points X,Y
# h2 = Set of points X,Y
# k = 0 used for calculating the distance between the same points 
# k = 1 used for calculationg distance between different points
# k = 2 used for plotting in the major direction
# k = 3 used for plotting in the minor direction
def C_Z(h1,h2,k):
    C = []
    nstruct = 1
    vtype = [3]
    a_max = [24]
    a_min = [16]
    Azimuth = 90
    cc = [1]
    c= 0
    for i in range(nstruct):
        Q1 = h1.copy()
        Q2 = h2.copy()
        if k == 0:
            d = distance_matrix(np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])),
                                np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i])))
        elif k == 1:
            d = np.sqrt(np.square((np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])))- 
                              np.tile((np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i]))),(k,1))).sum(axis=1))
            d = np.asarray(d).reshape(len(d))
        elif k == 2:
            d = Q1/a_max[i]
        elif k == 3:
            d = Q1/a_min[i]
        c = c + covar(vtype[i],d,1)*cc[i]
    return c

# %% [markdown]
# ## Secondary Correlogram

# %%
# h1 = Set of points X,Y
# h2 = Set of points X,Y
# k = 0 used for calculating the distance between the same points 
# k = 1 used for calculationg distance between different points
# k = 2 used for plotting in the major direction
# k = 3 used for plotting in the minor direction
def C_Y(h1,h2,k):
    C = []
    nstruct = 2
    vtype = [1,3]
    a_max = [42,43]
    a_min = [28.5,30]
    Azimuth = 90
    cc = [0.9,0.1]
    c= 0
    for i in range(nstruct):
        Q1 = h1.copy()
        Q2 = h2.copy()   
        if k == 0:
            d = distance_matrix(np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])),
                                np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i])))
        elif k == 1:
            d = np.sqrt(np.square((np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])))- 
                              np.tile((np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i]))),(k,1))).sum(axis=1))
            d = np.asarray(d).reshape(len(d))
        elif k == 2:
            d = Q1/a_max[i]
        elif k == 3:
            d = Q1/a_min[i]
        c = c + covar(vtype[i],d,1)*cc[i]
    return c

# %% [markdown]
# ## Scaling Correlogram

# %%
# h1 = Set of points X,Y
# h2 = Set of points X,Y
# k = 0 used for calculating the distance between the same points 
# k = 1 used for calculationg distance between different points
# k = 2 used for plotting in the major direction
# k = 3 used for plotting in the minor direction
def C_r(h1,h2,k):
    C = []
    nstruct = 1
    vtype = [3]
    a_max = [18]
    a_min = [13]
    Azimuth = 90
    cc = [1]
    c= 0
    for i in range(nstruct):
        Q1 = h1.copy()
        Q2 = h2.copy()
        if k == 0:
            d = distance_matrix(np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])),
                                np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i])))
        elif k == 1:
            d = np.sqrt(np.square((np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])))- 
                              np.tile((np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i]))),(k,1))).sum(axis=1))
            d = np.asarray(d).reshape(len(d))
        elif k == 2:
            d = Q1/a_max[i]
        elif k == 3:
            d = Q1/a_min[i]
        c = c + covar(vtype[i],d,1)*cc[i]
    return c

# %% [markdown]
# ## C_Z Correlogram MM2

# %%
# h1 = Set of points X,Y
# h2 = Set of points X,Y
# Corr = correlation between primary and secondary data
# k = 0 used for calculating the distance between the same points 
# k = 1 used for calculationg distance between different points
# k = 2 used for plotting in the major direction
# k = 3 used for plotting in the minor direction
def C_Z_MM2(h1,h2,k,corr): 
    return ((C_Y(h1,h2,k) * corr**2) + ((1-corr**2) * C_r(h1,h2,k)))

# %% [markdown]
# ## Plots Correlogram Models

# %%
corr = np.corrcoef(datafl['Primary'],datafl['Secondary'])[0,1]
cy = np.zeros(shape=(51))
cz_True = np.zeros(shape=(51))
cr = np.zeros(shape=(51))
cz = np.zeros(shape=(51))
H =np.zeros(shape=(51))
ones = np.zeros(shape=(51))
for h in range(0,51):
    cy[h] = C_Y(np.matrix(h),np.matrix(h),2)
    cz_True[h] = C_Z(np.matrix(h),np.matrix(h),2)
    cz[h] = C_Z_MM2(np.matrix(h),np.matrix(h),2,corr)
    cr[h] = C_r(np.matrix(h),np.matrix(h),2)
    H[h] = h
fig, axes = plt.subplots(1,1, figsize=(10,10))
axes.plot(H,cz,color = 'Blue',label = '$\u03C1_{z_{MM2}}$')
axes.plot(H,cz_True,color= 'red',label = '$\u03C1_{z_{True}}$')
axes.plot(H,cy,color = 'Green',label = '$\u03C1_{y}$')
axes.plot(varcalcfl_1['Lag Distance'][varcalcfl_1['Variogram Index']==1]
               ,1-varcalcfl_1['Variogram Value'][varcalcfl_1['Variogram Index']==1]
               ,'ro',color ='Red',label = '$\hat{\u03C1_{z}}$')
axes.plot(varcalcfl_2['Lag Distance'][varcalcfl_2['Variogram Index']==1]
               ,1-varcalcfl_2['Variogram Value'][varcalcfl_2['Variogram Index']==1]
               ,'ro',color ='Green',label = '$\hat{\u03C1_{y}}$')
axes.plot(H,ones,color = 'Black')
axes.grid()
plt.xlim(0,51)
plt.xticks(np.arange(min(H), max(H)+1, 10))
plt.ylim(-0.1,1)
plt.yticks(np.arange(-0.1, 1, 0.1))
plt.ylabel('\u03C1(h)',size=35)
plt.xlabel('h',size=35)
plt.title('MMI and MMII Correlogram Comparison Major Direction',size = 25)
axes.legend(loc='best', prop={"size":35})
plt.savefig('../0-Figures/MM1_MM2_var_major')

# %%
corr = np.corrcoef(datafl['Primary'],datafl['Secondary'])[0,1]
cy = np.zeros(shape=(51))
cz_True = np.zeros(shape=(51))
cr = np.zeros(shape=(51))
cz = np.zeros(shape=(51))
H =np.zeros(shape=(51))
ones = np.zeros(shape=(51))
for h in range(0,51):
    cy[h] = C_Y(np.matrix(h),np.matrix(h),3)
    cz_True[h] = C_Z(np.matrix(h),np.matrix(h),3)
    cz[h] = C_Z_MM2(np.matrix(h),np.matrix(h),3,corr)
    cr[h] = C_r(np.matrix(h),np.matrix(h),3)
    H[h] = h
fig, axes = plt.subplots(1,1, figsize=(10,10))
axes.plot(H,cz,color = 'Blue',label = '$\u03C1_{z_{MM2}}$')
axes.plot(H,cz_True,color= 'red',label = '$\u03C1_{z_{True}}$')
axes.plot(H,cy,color = 'Green',label = '$\u03C1_{y}$')
axes.plot(varcalcfl_1['Lag Distance'][varcalcfl_1['Variogram Index']==2]
               ,1-varcalcfl_1['Variogram Value'][varcalcfl_1['Variogram Index']==2]
               ,'ro',color ='Red',label = '$\hat{\u03C1_{z}}$')
axes.plot(varcalcfl_2['Lag Distance'][varcalcfl_2['Variogram Index']==2]
               ,1-varcalcfl_2['Variogram Value'][varcalcfl_2['Variogram Index']==2]
               ,'ro',color ='Green',label = '$\hat{\u03C1_{y}}$')
axes.plot(H,ones,color = 'Black')
axes.grid()
plt.xlim(0,51)
plt.xticks(np.arange(min(H), max(H)+1, 10))
plt.ylim(-0.1,1)
plt.yticks(np.arange(-0.1, 1, 0.1))
plt.ylabel('\u03C1(h)',size=35)
plt.xlabel('h',size=35)
plt.title('MMI and MMII Correlogram Comparison Minor Direction',size = 25)
axes.legend(loc='best', prop={"size":35})
plt.savefig('../0-Figures/MM1_MM2_var_Minor')

# %% [markdown]
# ## Cross Correlogram

# %%
def C_ZY(h1,h2,k,corr):
    C = []
    nstruct = 1
    vtype = [1]
    a_max = [45]
    a_min = [30]
    Azimuth = 90
    cc = [corr]
    c= 0
    for i in range(nstruct):
        Q1 = h1.copy()
        Q2 = h2.copy()
        if k == 0:
            d = distance_matrix(np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])),
                                np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i])))
        elif k == 1:
            d = np.sqrt(np.square((np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])))- 
                              np.tile((np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i]))),(k,1))).sum(axis=1))
            d = np.asarray(d).reshape(len(d))
        elif k == 2:
            d = Q1/a_max[i]
        elif k == 3:
            d = Q1/a_min[i]
        c = c + covar(vtype[i],d,1)*cc[i]
    return c

# %% [markdown]
# ## LMC

# %% [markdown]
# The new variogram that will be used for full cokriging, these variograms will be slightly differnt the variograms modelled above. For LMC variograms the sill should be the variance of the variable for the primary and secondary variables. The correlations is the sill of the cross-correlogram

# %% [markdown]
# ### Primary

# %%
# h1 = Set of points X,Y
# h2 = Set of points X,Y
# k = 0 used for calculating the distance between the same points 
# k = 1 used for calculationg distance between different points
# k = 2 used for plotting in the major direction
# k = 3 used for plotting in the minor direction
def C_Z_LMC(h1,h2,k):
    C = []
    nstruct = 2
    vtype = [1,1]
    a_max = [33,40]
    a_min = [15,30]
    Azimuth = 90
    cc = [0.85,0.15]
    c = 0
    for i in range(nstruct):
        Q1 = h1.copy()
        Q2 = h2.copy()
        if k == 0:
            d = distance_matrix(np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])),
                                np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i])))
        elif k == 1:
            d = np.sqrt(np.square((np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])))- 
                              np.tile((np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i]))),(k,1))).sum(axis=1))
            d = np.asarray(d).reshape(len(d))
        elif k == 2:
            d = Q1/a_max[i]
        elif k == 3:
            d = Q1/a_min[i]
        c = c + covar(vtype[i],d,1)*cc[i]
    return c

# %% [markdown]
# ### Secondary

# %%
# h1 = Set of points X,Y
# h2 = Set of points X,Y
# k = 0 used for calculating the distance between the same points 
# k = 1 used for calculationg distance between different points
# k = 2 used for plotting in the major direction
# k = 3 used for plotting in the minor direction
def C_Y_LMC(h1,h2,k):
    C = []
    nstruct = 2
    vtype = [1,1]
    a_max = [33,40]
    a_min = [15,30]
    Azimuth = 90
    cc = [0.25,0.75]
    c= 0
    for i in range(nstruct):
        Q1 = h1.copy()
        Q2 = h2.copy()
        if k == 0:
            d = distance_matrix(np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])),
                                np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i])))
        elif k == 1:
            d = np.sqrt(np.square((np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])))- 
                              np.tile((np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i]))),(k,1))).sum(axis=1))
            d = np.asarray(d).reshape(len(d))
        elif k == 2:
            d = Q1/a_max[i]
        elif k == 3:
            d = Q1/a_min[i]
        c = c + covar(vtype[i],d,1)*cc[i]
    return c

# %% [markdown]
# ### Cross

# %%
# h1 = Set of points X,Y
# h2 = Set of points X,Y
# Corr = correlation between primary and secondary data
# k = 0 used for calculating the distance between the same points 
# k = 1 used for calculationg distance between different points
# k = 2 used for plotting in the major direction
# k = 3 used for plotting in the minor direction
def C_ZY_LMC(h1,h2,k,corr):
    C = []
    nstruct = 2
    vtype = [1,1]
    a_max = [33,40]
    a_min = [15,30]
    Azimuth = 90
    cc = [corr*0.6,corr*0.4]
    c= 0
    for i in range(nstruct):
        Q1 = h1.copy()
        Q2 = h2.copy()
        if k == 0:
            d = distance_matrix(np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])),
                                np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i])))
        elif k == 1:
            d = np.sqrt(np.square((np.matmul(Q1,Rot_Mat(Azimuth,a_max[i],a_min[i])))- 
                              np.tile((np.matmul(Q2,Rot_Mat(Azimuth,a_max[i],a_min[i]))),(k,1))).sum(axis=1))
            d = np.asarray(d).reshape(len(d))
        elif k == 2:
            d = Q1/a_max[i]
        elif k == 3:
            d = Q1/a_min[i]
        c = c + covar(vtype[i],d,1)*cc[i]
    return c

# %%
s_1 = np.array([[0.0001, 0],
              [0, 0.0001]])
s_2 = np.array([[0.85, corr*0.6],
              [corr*0.6,0.25]])
s_3 = np.array([[0.15, corr*0.4],
              [corr*0.4,0.75]])

print(np.linalg.det(s_1))
print(np.linalg.det(s_2))
print(np.linalg.det(s_3))
print(s_1+s_2+s_3)
# Out:
# 1.0000000000000018e-08
# 0.02601118558622158
# 0.02961608248276517
# [[1.   0.72]
#  [0.72 1.  ]]

# %% [markdown]
# ### Plot LMC

# %%
cy = np.zeros(shape=(51))
cz_True = np.zeros(shape=(51))
cz = np.zeros(shape=(51))
czy = np.zeros(shape=(51))
cy_LMC = np.zeros(shape=(51))
cz_LMC = np.zeros(shape=(51))
czy_LMC = np.zeros(shape=(51))
H =np.zeros(shape=(51))
ones = np.zeros(shape=(51))
for h in range(0,51):
    cy[h] = C_Y(np.matrix(h),np.matrix(h),2)
    cz_True[h] = C_Z(np.matrix(h),np.matrix(h),2)
    czy[h] = C_ZY(np.matrix(h),np.matrix(h),2,corr)
    H[h] = h
fig, axes = plt.subplots(1,1, figsize=(10,10))
axes.plot(H,cz_True,color= 'red',label = '$\u03C1_{z}$')
axes.plot(H,cy,color = 'Green',label = '$\u03C1_{y}$')
axes.plot(H,czy,color = 'Blue',label = '$\u03C1_{zy}$')


for h in range(0,51):
    cy_LMC[h] = C_Y_LMC(np.matrix(h),np.matrix(h),2)
    cz_LMC[h] = C_Z_LMC(np.matrix(h),np.matrix(h),2)
    czy_LMC[h] = C_ZY_LMC(np.matrix(h),np.matrix(h),2,corr)

axes.plot(H,cz_LMC,color= 'Orange',label = '$\u03C1_{z_{LMC}}$')
axes.plot(H,cy_LMC,color = 'Yellow',label = '$\u03C1_{y_{LMC}}$')
axes.plot(H,czy_LMC,color = 'Grey',label = '$\u03C1_{zy_{LMC}}$')


axes.plot(varcalcfl_1['Lag Distance'][varcalcfl_1['Variogram Index']==1]
               ,1-varcalcfl_1['Variogram Value'][varcalcfl_1['Variogram Index']==1]
               ,'ro',color ='Red',label = '$\hat{\u03C1_{z}}$')
axes.plot(varcalcfl_2['Lag Distance'][varcalcfl_2['Variogram Index']==1]
               ,1-varcalcfl_2['Variogram Value'][varcalcfl_2['Variogram Index']==1]
               ,'ro',color ='Green',label = '$\hat{\u03C1_{y}}$')
axes.plot(varcalcfl_3['Lag Distance'][varcalcfl_3['Variogram Index']==1]
               ,corr-varcalcfl_3['Variogram Value'][varcalcfl_3['Variogram Index']==1]
               ,'ro',color ='Blue',label = '$\hat{\u03C1_{zy}}$')
axes.plot(H,ones,color = 'Black')
axes.grid()
plt.xlim(0,29)
plt.xticks(np.arange(min(H), max(H)+1, 1.0))
plt.ylim(-0.1,1)
plt.yticks(np.arange(-0.1, 1, 0.1))
plt.ylabel('\u03C1(h)',size=35)
plt.xlabel('h',size=35)
plt.title('LMC - Major',size = 35)
axes.legend(loc='best', prop={"size":15})
plt.savefig('../0-Figures/LMC_Major')

# %%
cy = np.zeros(shape=(51))
cz_True = np.zeros(shape=(51))
cz = np.zeros(shape=(51))
czy = np.zeros(shape=(51))
cy_LMC = np.zeros(shape=(51))
cz_LMC = np.zeros(shape=(51))
czy_LMC = np.zeros(shape=(51))
H =np.zeros(shape=(51))
ones = np.zeros(shape=(51))
for h in range(0,51):
    cy[h] = C_Y(np.matrix(h),np.matrix(h),3)
    cz_True[h] = C_Z(np.matrix(h),np.matrix(h),3)
    czy[h] = C_ZY(np.matrix(h),np.matrix(h),3,corr)
    H[h] = h
fig, axes = plt.subplots(1,1, figsize=(10,10))
axes.plot(H,cz_True,color= 'red',label = '$\u03C1_{z}$')
axes.plot(H,cy,color = 'Green',label = '$\u03C1_{y}$')
axes.plot(H,czy,color = 'Blue',label = '$\u03C1_{zy}$')


for h in range(0,51):
    cy_LMC[h] = C_Y_LMC(np.matrix(h),np.matrix(h),3)
    cz_LMC[h] = C_Z_LMC(np.matrix(h),np.matrix(h),3)
    czy_LMC[h] = C_ZY_LMC(np.matrix(h),np.matrix(h),3,corr)

axes.plot(H,cz_LMC,color= 'Orange',label = '$\u03C1_{z_{LMC}}$')
axes.plot(H,cy_LMC,color = 'Yellow',label = '$\u03C1_{y_{LMC}}$')
axes.plot(H,czy_LMC,color = 'Grey',label = '$\u03C1_{zy_{LMC}}$')


axes.plot(varcalcfl_1['Lag Distance'][varcalcfl_1['Variogram Index']==2]
               ,1-varcalcfl_1['Variogram Value'][varcalcfl_1['Variogram Index']==2]
               ,'ro',color ='Red',label = '$\hat{\u03C1_{z}}$')
axes.plot(varcalcfl_2['Lag Distance'][varcalcfl_2['Variogram Index']==2]
               ,1-varcalcfl_2['Variogram Value'][varcalcfl_2['Variogram Index']==2]
               ,'ro',color ='Green',label = '$\hat{\u03C1_{y}}$')
axes.plot(varcalcfl_3['Lag Distance'][varcalcfl_3['Variogram Index']==2]
               ,corr-varcalcfl_3['Variogram Value'][varcalcfl_3['Variogram Index']==2]
               ,'ro',color ='Blue',label = '$\hat{\u03C1_{zy}}$')
axes.plot(H,ones,color = 'Black')
axes.grid()
plt.xlim(0,29)
plt.xticks(np.arange(min(H), max(H)+1, 1.0))
plt.ylim(-0.1,1)
plt.yticks(np.arange(-0.1, 1, 0.1))
plt.ylabel('\u03C1(h)',size=35)
plt.xlabel('h',size=35)
plt.title('LMC - Minor',size = 35)
axes.legend(loc='best', prop={"size":15})
plt.savefig('../0-Figures/LMC_Minor')

# %% [markdown]
# # Kriging

# %% [markdown]
# ## Data Statistics

# %%
Mean_Z = np.average(datafl['Primary'])
STD_Z = 1.0
print(Mean_Z)
print(STD_Z)
# Out:
# -0.42471875000000003
# 1.0

# %%
Mean_Y = np.average(datafl['Secondary'])
STD_Y = 1.0
print(Mean_Y)
print(STD_Y)
# Out:
# -0.19742499999999996
# 1.0

# %%
corr = np.corrcoef(datafl['Primary'],datafl['Secondary'])[0,1]
print(corr)
# Out:
# 0.7197391780935075

# %% [markdown]
# ## Create a KDTree to Quickly Get Nearest Points

# %%
from sklearn.neighbors import KDTree

# %%
datafl_XY = datafl.as_matrix(['X', 'Y']) #prediction grid
tree = KDTree(datafl_XY)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
Pred_grid_xy = np.matrix([x,y]).T

# %%
k = 60 #number of data to use
X_Y = np.zeros((len(x),k,2))
X_Y_Star = np.zeros((len(x),k,2))
closematrix_Primary = np.zeros((len(x),k))
closematrix_Secondary = np.zeros((len(x),k))
neardistmatrix = np.zeros((len(x),k))
for i in range (0,len(x)):
    nearest_dist, nearest_ind = tree.query(Pred_grid_xy[i:i+1,:], k=k)
    a  = nearest_ind.ravel()
    group = datafl.iloc[a,:]
    closematrix_Primary[i,:] = group['Primary']
    closematrix_Secondary[i,:] = group['Secondary']
    neardistmatrix[i,:] = nearest_dist
    X_Y[i,:,:] = group[['X','Y']]

# %%
datafl_XY_2nd = datafl_sec.as_matrix(['X', 'Y'])
tree_2nd = KDTree(datafl_XY_2nd)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
k = k #number of neighbours
X_Y_2nd = np.zeros((len(x),k,2))
closematrix_Secondary_2nd = np.zeros((len(x),k))
for i in range (0,len(x)):
    nearest_dist, nearest_ind = tree_2nd.query(Pred_grid_xy[i:i+1,:], k=k)
    a  = nearest_ind.ravel()
    group = datafl_sec.iloc[a,:]
    closematrix_Secondary_2nd[i,:] = group['Secondary']
    X_Y_2nd[i,:,:] = group[['X','Y']]

# %% [markdown]
# ## Ordinary Kriging

# %%
est_OK = np.zeros(shape = (len(x)))
for z in tqdm(range(0,len(x))):
    Kriging_Matrix = np.zeros(shape=((k+1,k+1)))
    #h = distance_matrix(X_Y[z,:,:].tolist(),X_Y[z,:,:].tolist())
    #C_ZZ
    Kriging_Matrix[0:k,0:k] = C_Z(X_Y[z,:,:],X_Y[z,:,:],0)
    #Last row = 1
    Kriging_Matrix[k,0:k+1] = 1
    #Last Column = 1
    Kriging_Matrix[0:k+1,k] = 1
    Kriging_Matrix[k,k] = 0
    #Set up Right Hand Side
    #print(Kriging_Matrix.reshape(((k)),((k))))
    r = np.zeros(shape=(k+1))
    k_weights = r
    #RHS #C_z*
    r[0:k] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1)
    # Set lagrange  = 1
    r[k] = 1
    #Calculate Kriging Weights
    try:
        k_weights = np.dot(np.linalg.inv(Kriging_Matrix),r)
    except:
        s_m = s_m+1
        sm_idx.append(z)
        k_weights = np.dot(scipy.linalg.pinv(Kriging_Matrix),r)
    #Start Est at zero
    est_OK[z] = 0
    for i in range (0,k):
        #add in Z_i
        est_OK[z] = est_OK[z] + k_weights[i]*(closematrix_Primary[z,i])
#print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:31<00:00, 322.18it/s]

# %% [markdown]
# ## Full Cokriging

# %%
h = np.zeros(shape = (k,k))
cz = np.zeros(shape = (k,k))
czy = np.zeros(shape = (k,k))
czy_2 = np.zeros(shape = (k,k))
cy = np.zeros(shape = (k,k))
s_m = 0
sm_idx = []
est_Full_CCK = np.zeros(shape = (len(x)))
for z in tqdm(range(0,len(x))):
    Kriging_Matrix = np.zeros(shape=((k*2+1+1),(k*2+1+1)))
    #C_ZZ
    cz = C_Z_LMC(X_Y[z,:,:],X_Y[z,:,:],0)
    #C_ZY
    czy = C_ZY_LMC(X_Y[z,:,:],X_Y_2nd[z,:,:],0,corr)
    czy_2 = C_ZY_LMC(X_Y_2nd[z,:,:],X_Y[z,:,:],0,corr)
    #C_YY
    cy = C_Y_LMC(X_Y_2nd[z,:,:],X_Y_2nd[z,:,:],0)  
    Kriging_Matrix[0:k*2,0:k*2] = np.vstack((np.hstack((cz,czy)),np.hstack((czy.T,cy))))
    #2nd Last row = 1,Primary
    Kriging_Matrix[k*2,0:k] = 1
    #2nd Last Column = 1,Primary
    Kriging_Matrix[0:k,k*2] = 1
    #Last row = 1,Secondary
    Kriging_Matrix[k*2+1,k:k*2] = 1
    #Last Column = 1,Secondary
    Kriging_Matrix[k:k*2,k*2+1] = 1
    #print(Kriging_Matrix)
    #Set up Right Hand Sides
    r = np.zeros(shape=(k*2+1+1))
    k_weights = r
    #RHS #C_z*
    r[0:k] = C_Z_LMC(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1)
    #RHS #C_zy*
    r[k:k*2] = C_ZY_LMC(X_Y_2nd[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1,corr)
    #Primary Set lagrange  = 1
    r[k*2] = 1
    #Secondary Set lagrange  = 0
    r[k*2+1] = 0
    #Calculate Kriging Weights
    try:
        k_weights = np.dot(np.linalg.inv(Kriging_Matrix),r)
    except:
        s_m = s_m+1
        sm_idx.append(z)
        k_weights = np.dot(scipy.linalg.pinv(Kriging_Matrix),r)
    #Start Est at zero
    est_Full_CCK[z] = 0
    for i in range (0,k):
        #add in Z_i
        est_Full_CCK[z] = est_Full_CCK[z] + k_weights[i] * (closematrix_Primary[z,i])
        #add in Y_i
        est_Full_CCK[z] = est_Full_CCK[z] + k_weights[i+k] * (closematrix_Secondary_2nd[z,i])
print('There where {} Singular Matrices'.format(s_m))
#print(Kriging_Matrix.reshape(((2*k)),((2*k))))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:40<00:00, 99.93it/s]
# There where 0 Singular Matrices

# %% [markdown]
# ## Ordinary Collocated Cokriging - MM1

# %%
est_MM1 = np.zeros(shape = (len(x)))
for z in tqdm(range(0,len(x))):
    Kriging_Matrix = np.zeros(shape=((k+1+1),(k+1+1)))
    #C_ZZ
    Kriging_Matrix[0:k,0:k] = C_Z(X_Y[z,:,:],X_Y[z,:,:],0)
    #Set up Right Hand Side
    #print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
    r = np.zeros(shape=(k+1+1))
    k_weights = r
    #RHS #C_z*
    r[0:k] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1)
    #RHS corr
    r[k] = corr
    # Set lagrange  = 1
    r[k+1] = 1
    #c_zy
    Kriging_Matrix[k,0:k+1] = r[0:k+1] * corr
    Kriging_Matrix[0:k+1,k] = r[0:k+1] * corr
    Kriging_Matrix[k,k] = 1
    #Last row = 1
    Kriging_Matrix[k+1,0:k] = 1
    #Last column = 1
    Kriging_Matrix[0:k,k+1] = 1
    #Calculate Kriging Weights
    try:
        k_weights = np.dot(np.linalg.inv(Kriging_Matrix),r)
    except:
        s_m = s_m+1
        sm_idx.append(z)
        k_weights = np.dot(scipy.linalg.pinv(Kriging_Matrix),r)
    #Start Est at zero
    est_MM1[z] = 0
    #add in the Y_0
    est_MM1[z] = est_MM1[z] + k_weights[k] * (datafl_sec['Secondary'][z])
    for i in range (0,k):
        #add in Z_i
        est_MM1[z] = est_MM1[z] + k_weights[i] * (closematrix_Primary[z,i])
#print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:31<00:00, 321.25it/s]

# %% [markdown]
# ## Ordinary Collocated Cokriging - MM2

# %%
est_MM2 = np.zeros(shape = (len(x)))
s_m = 0
sm_idx =[]
for z in tqdm(range(0,len(x))):
    Kriging_Matrix = np.zeros(shape=((k+1+1),(k+1+1)))
    #C_ZZ
    Kriging_Matrix[0:k,0:k] = C_Z_MM2(X_Y[z,:,:],X_Y[z,:,:],0,corr)
    #Set up Right Hand Side
    #print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
    r = np.zeros(shape=(k+1+1))
    k_weights = r
    #RHS #C_z*
    r[0:k] = C_Z_MM2(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1,corr)
    #RHS corr
    r[k] = corr
    # Set lagrange  = 1
    r[k+1] = 1
    #c_zy
    Kriging_Matrix[k,0:k] = C_Y(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    Kriging_Matrix[0:k,k] = C_Y(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    Kriging_Matrix[k,k] = 1
    #Last row = 1
    Kriging_Matrix[k+1,0:k] = 1
    #Last column = 1
    Kriging_Matrix[0:k,k+1] = 1
    Kriging_Matrix[k+1,k+1] = 0
    #Calculate Kriging Weights
    try:
        k_weights = np.dot(np.linalg.inv(Kriging_Matrix),r)
    except:
        s_m = s_m+1
        sm_idx.append(z)
        k_weights = np.dot(scipy.linalg.pinv(Kriging_Matrix),r)
    #Start Est at zero
    est_MM2[z] = 0
    #add in the Y_0
    est_MM2[z] = est_MM2[z] + k_weights[k] * (datafl_sec['Secondary'][z])
    for i in range (0,k):
        #add in Z_i
        est_MM2[z] = est_MM2[z] + k_weights[i] * (closematrix_Primary[z,i])
#print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
print('There where {} Singular Matrices'.format(s_m))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:44<00:00, 226.96it/s]
# There where 0 Singular Matrices

# %%
Kriging_Matrix
# Out:
# array([[1.000e+00, 2.400e-01, 4.179e-01, ..., 4.619e-13, 4.766e-01,
#         1.000e+00],
#        [2.400e-01, 1.000e+00, 1.612e-01, ..., 5.015e-11, 1.249e-01,
#         1.000e+00],
#        [4.179e-01, 1.612e-01, 1.000e+00, ..., 1.247e-11, 2.554e-01,
#         1.000e+00],
#        ...,
#        [4.619e-13, 5.015e-11, 1.247e-11, ..., 1.000e+00, 9.698e-15,
#         1.000e+00],
#        [4.766e-01, 1.249e-01, 2.554e-01, ..., 9.698e-15, 1.000e+00,
#         0.000e+00],
#        [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 0.000e+00,
#         0.000e+00]])

# %%
r
# Out:
# array([5.404e-01, 9.087e-02, 1.961e-01, 4.307e-02, 4.727e-02, 2.100e-03,
#        4.198e-03, 1.291e-03, 4.778e-04, 2.231e-03, 9.619e-05, 5.912e-05,
#        8.206e-04, 1.065e-04, 2.189e-05, 2.995e-04, 1.555e-06, 9.556e-07,
#        1.102e-04, 4.879e-06, 3.537e-07, 1.430e-05, 2.422e-05, 8.868e-09,
#        7.887e-08, 6.552e-07, 8.911e-06, 5.450e-09, 1.157e-06, 2.018e-09,
#        1.059e-08, 5.299e-08, 4.498e-10, 1.180e-06, 1.785e-11, 4.340e-07,
#        1.097e-11, 5.634e-08, 4.061e-12, 8.564e-10, 6.040e-11, 2.581e-09,
#        9.053e-13, 3.461e-08, 1.267e-14, 1.273e-08, 7.790e-15, 4.885e-12,
#        4.172e-11, 1.216e-13, 2.884e-15, 1.653e-09, 7.571e-11, 6.429e-16,
#        2.379e-13, 9.831e-15, 1.224e-12, 8.633e-17, 4.789e-16, 6.980e-15,
#        7.197e-01, 1.000e+00])

# %%
k_weights
# Out:
# array([ 0.33 , -0.023, -0.061, -0.003,  0.02 ,  0.025,  0.01 ,  0.014,
#         0.012,  0.019,  0.018,  0.007,  0.014,  0.01 ,  0.01 ,  0.013,
#         0.02 ,  0.009,  0.008,  0.011,  0.011,  0.011,  0.015,  0.019,
#         0.011,  0.011,  0.01 ,  0.009,  0.011,  0.011,  0.011,  0.011,
#         0.012,  0.013,  0.018,  0.007,  0.007,  0.009,  0.009,  0.011,
#         0.011,  0.008,  0.01 ,  0.024,  0.025,  0.018,  0.013,  0.01 ,
#         0.008,  0.009,  0.014,  0.02 ,  0.019,  0.014,  0.008,  0.011,
#         0.019,  0.023,  0.023,  0.023,  0.579, -0.038])

# %%
np.dot(np.linalg.inv(Kriging_Matrix),r)
# Out:
# array([ 0.33 , -0.023, -0.061, -0.003,  0.02 ,  0.025,  0.01 ,  0.014,
#         0.012,  0.019,  0.018,  0.007,  0.014,  0.01 ,  0.01 ,  0.013,
#         0.02 ,  0.009,  0.008,  0.011,  0.011,  0.011,  0.015,  0.019,
#         0.011,  0.011,  0.01 ,  0.009,  0.011,  0.011,  0.011,  0.011,
#         0.012,  0.013,  0.018,  0.007,  0.007,  0.009,  0.009,  0.011,
#         0.011,  0.008,  0.01 ,  0.024,  0.025,  0.018,  0.013,  0.01 ,
#         0.008,  0.009,  0.014,  0.02 ,  0.019,  0.014,  0.008,  0.011,
#         0.019,  0.023,  0.023,  0.023,  0.579, -0.038])

# %% [markdown]
# ## Intrinsic Collocated Cokriging - MM1

# %%
s_m = 0
sm_idx =[]
cz = np.zeros(shape = (k,k))
czy = np.zeros(shape = (k,k))
cy = np.zeros(shape = (k,k))
est_icck_MM1 = np.zeros(shape = (len(x)))
for z in tqdm(range(0,len(x))):
    Kriging_Matrix = np.zeros(shape=((k*2+1+1+1),(k*2+1+1+1)))
    #C_ZZ
    cz = C_Z(X_Y[z,:,:],X_Y[z,:,:],0)
    #C_ZY
    czy = C_Z(X_Y[z,:,:],X_Y[z,:,:],0) * corr
    #C_YY
    cy = C_Z(X_Y[z,:,:],X_Y[z,:,:],0)
    #Set up Right Hand Side
    Kriging_Matrix[0:k*2,0:k*2] = np.vstack((np.hstack((cz,czy)),np.hstack((czy.T,cy))))
    #print(Kriging_Matrix)
    r = np.zeros(shape=(k*2+1+1+1))
    k_weights = r
    #RHS #C_z*
    r[0:k] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1)
    #RHS #C_yz*
    r[k:k*2] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    #RHS corr
    r[k*2] = corr
    # Set Primary lagrange  = 1
    r[k*2+1] = 1
    # Set Seconadry lagrange  = 0
    r[k*2+2] = 0
    #c_zy
    Kriging_Matrix[k*2,0:k] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    Kriging_Matrix[0:k,k*2] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    #c_z
    Kriging_Matrix[k*2,k:k*2] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1)
    Kriging_Matrix[k:k*2,k*2] = C_Z(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1)    
    Kriging_Matrix[k*2,k*2] = 1
    #2nd Last row = 1,Primary
    Kriging_Matrix[k*2+1,0:k] = 1
    #2nd Last Column = 1,Primary
    Kriging_Matrix[0:k,k*2+1] = 1
    #Last row = 1,secondary
    Kriging_Matrix[k*2+1+1,k:k*2] = 1
    #Last Column = 1,secondary
    Kriging_Matrix[k:k*2,k*2+1+1] = 1
    #Calculate Kriging Weights
    try:
        k_weights = np.dot(np.linalg.inv(Kriging_Matrix),r)
    except:
        s_m = s_m+1
        sm_idx.append(z)
        k_weights = np.dot(scipy.linalg.pinv(Kriging_Matrix),r)
    #Start Est at zero
    est_icck_MM1[z] = 0
    #add in the Y_0
    est_icck_MM1[z] = est_icck_MM1[z] + k_weights[k*2] * (datafl_sec['Secondary'][z])
    for i in range (0,k):
        #add in Z_i
        est_icck_MM1[z] = est_icck_MM1[z] + k_weights[i] * (closematrix_Primary[z,i])
        #add in Y_i
        est_icck_MM1[z] = est_icck_MM1[z] + k_weights[i+k] * (closematrix_Secondary[z,i])
#print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
print('There where {} Singular Matrices'.format(s_m))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:26<00:00, 115.31it/s]
# There where 0 Singular Matrices

# %%
est_icck_MM1
# Out:
# array([ 0.587,  0.481,  0.573, ..., -0.746, -0.665, -0.585])

# %% [markdown]
# ## Intrinsic Collocated Cokriging - MM2

# %%
s_m = 0
sm_idx =[]
cz = np.zeros(shape = (k,k))
czy = np.zeros(shape = (k,k))
cy = np.zeros(shape = (k,k))
est_icck_MM2 = np.zeros(shape = (len(x)))
for z in tqdm(range(0,len(x))):
    Kriging_Matrix = np.zeros(shape=((k*2+1+1+1),(k*2+1+1+1)))
    #C_ZZ
    #1
    cz = C_Z_MM2(X_Y[z,:,:],X_Y[z,:,:],0,corr)
    #C_ZY
    #2,#3
    czy = corr * C_Y(X_Y[z,:,:],X_Y[z,:,:],0)
    #C_YY
    #4
    cy = C_Y(X_Y[z,:,:],X_Y[z,:,:],0)
    #Set up Right Hand Side
    #print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
    Kriging_Matrix[0:k*2,0:k*2] = np.vstack((np.hstack((cz,czy)),np.hstack((czy.T,cy))))
    r = np.zeros(shape=(k*2)+1+1+1)
    k_weights = r
    #RHS #C_z*
    #5
    r[0:k] = C_Z_MM2(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1,corr)
    #RHS #C_yz*
    #6
    r[k:k*2] = C_Y(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    #RHS corr
    #7
    r[k*2] = corr
    # Set Primary lagrange  = 1
    r[k*2+1] = 1
    # Set Seconadry lagrange  = 0
    r[k*2+2] = 0
    #c_xy
    #8
    Kriging_Matrix[k*2,0:k] = C_Y(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    Kriging_Matrix[0:k,k*2] = C_Y(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) * corr
    #c_y
    #9
    Kriging_Matrix[k*2,k:k*2] = C_Y(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) 
    Kriging_Matrix[k:k*2,k*2]  = C_Y(X_Y[z,:,:],np.tile(Pred_grid_xy[z],(k,1)),1) 
    Kriging_Matrix[k*2,k*2] = 1
    #2nd Last row = 1,Primary
    Kriging_Matrix[k*2+1,0:k] = 1
    #2nd Last Column = 1,Primary
    Kriging_Matrix[0:k,k*2+1] = 1
    #Last row = 1,secondary
    Kriging_Matrix[k*2+1+1,k:k*2] = 1
    #Last Column = 1,secondary
    Kriging_Matrix[k:k*2,k*2+1+1] = 1
    #Calculate Kriging Weights
    try:
        k_weights = np.dot(np.linalg.inv(Kriging_Matrix),r)
    except:
        s_m = s_m+1
        sm_idx.append(z)
        k_weights = np.dot(scipy.linalg.pinv(Kriging_Matrix),r)
    #Start Est at zero
    est_icck_MM2[z] = 0
    #add in the Y_0
    est_icck_MM2[z] = est_icck_MM2[z] + k_weights[k*2] * (datafl_sec['Secondary'][z])
    for i in range (0,k):
        #add in Z_i
        est_icck_MM2[z] = est_icck_MM2[z] + k_weights[i] * (closematrix_Primary[z,i])
        #add in Y_i
        est_icck_MM2[z] = est_icck_MM2[z] + k_weights[i+k] * (closematrix_Secondary[z,i])
#print(Kriging_Matrix.reshape(((2*k)+1),((2*k)+1)))
print('There where {} Singular Matrices'.format(s_m))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:45<00:00, 94.75it/s]
# There where 0 Singular Matrices

# %% [markdown]
# ## Results

# %%
ktypes_vals_str = ['OK_Traditional','OCK_Traditional','CCOK_MM1_Traditional','CCOK_MM2_Traditional','OICCK_MM1_Traditional','OICCK_MM2_Traditional']
ktypes_vals = [est_OK,est_Full_CCK,est_MM1,est_MM2,est_icck_MM1,est_icck_MM2]

# %% [markdown]
# ### Pixelplt

# %%
#Set up Plotting Grid
fig = plt.figure(constrained_layout=True,figsize=(10,10))
gs = gridspec.GridSpec(3, 6,figure=fig)
gs.update(wspace=1,hspace=0.7)
ax1 = plt.subplot(gs[0, :2])
ax2 = plt.subplot(gs[0, 2:4])
ax3 = plt.subplot(gs[1, :2])
ax4 = plt.subplot(gs[1, 2:4])
ax5 = plt.subplot(gs[2, :2])
ax6 = plt.subplot(gs[2, 2:4])
ax7 = plt.subplot(gs[:,4])
#Generate Pixelplt
axes = [ax1,ax2,ax3,ax4,ax5,ax6]
XMIN, XMAX = 0, 100
YMIN, YMAX = 0, 100
SMIN, SMAX = -3,3
gridd = pd.DataFrame()
gridd['Y'] = y
gridd['X'] = x
for i in range(0,len(ktypes_vals)):
    gridd['Estimate'] = ktypes_vals[i]
    gridded = np.reshape(gridd.sort_values(by=['Y', 'X'], axis=0, ascending=True)['Estimate'].values,
                     [100, 100], order='C')
    ax = axes[i]
    ax.imshow(gridded, origin='lower', extent=[XMIN, XMAX, YMIN, YMAX], aspect='equal',
                interpolation='none', vmin=SMIN, vmax=SMAX, cmap='viridis')
    ax.set_title('{}'.format(ktypes_vals_str[i]),size=20)
    ax.set_xlabel('Easting',size=20)
    ax.set_ylabel('Northing',size=20)
norm = matplotlib.colors.Normalize(vmin=-3, vmax=3)
cb1 = matplotlib.colorbar.ColorbarBase(ax7, cmap= plt.get_cmap('viridis'),norm = norm) 
ax7.set_title('Grade',size=20)
plt.show()
fig.savefig('../0-Figures/estimates_UB.png')

# %% [markdown]
# ### Data Reproduction

# %%
#Set up Plotting Grid
fig = plt.figure(constrained_layout=True,figsize=(8,12))
gs = gridspec.GridSpec(3, 4,figure=fig)
gs.update(wspace=1,hspace=0.7)
ax1 = plt.subplot(gs[0, :2])
ax2 = plt.subplot(gs[0, 2:4])
ax3 = plt.subplot(gs[1, :2])
ax4 = plt.subplot(gs[1, 2:4])
ax5 = plt.subplot(gs[2, :2])
ax6 = plt.subplot(gs[2, 2:4])
axes = [ax1,ax2,ax3,ax4,ax5,ax6]
for i in range(0,len(ktypes_vals)):
    ax = axes[i]
    ax.scatter(ktypes_vals[i],truth['Primary'],color='Black')
    ax.plot(np.unique(truth['Primary']), 
             np.poly1d(np.polyfit(truth['Primary'], ktypes_vals[i], 1))(np.unique(truth['Primary'])),
            color = 'Red')
    ax.set_title('{}'.format(ktypes_vals_str[i]),size = 20)
    ax.set_xlim(-4,4)
    ax.set_ylim(-4,4)
    x_45 = np.linspace(*ax.get_xlim())
    ax.plot(x_45, x_45,color = 'blue')
    ax.set_xlabel('Estimate',size = 20)
    ax.set_ylabel('Truth',size = 20)
    ax.set_aspect('equal', 'box')
    ax.text(-3.5,3.0,'RMSE = {:.3f}'.format(np.sqrt(mean_squared_error(ktypes_vals[i],truth['Primary']))),size=15)
plt.show()
fig.savefig('../0-Figures/Scatter_true_UB.png')

# %% [markdown]
# ### Histogram Reproduction

# %%
mean = []
var = []
RMSE = []
ktypes_vals = [est_OK,est_Full_CCK,est_MM1,est_MM2,est_icck_MM1,est_icck_MM2]
mean.append(np.mean(datafl['Primary']))
var.append(np.var(datafl['Primary']))
RMSE.append(0)
for ktypes_vals in ktypes_vals:
    mean.append(np.mean(ktypes_vals))
    var.append(np.var(ktypes_vals))
    RMSE.append(np.sqrt(mean_squared_error(ktypes_vals,truth['Primary'])))

# %%
ktypes_vals = [est_OK,est_Full_CCK,est_MM1,est_MM2,est_icck_MM1,est_icck_MM2]
fig = plt.figure(constrained_layout=True,figsize=(8,12))
gs = gridspec.GridSpec(3, 4,figure=fig)
gs.update(wspace=1,hspace=0.7)
ax1 = plt.subplot(gs[0, :2])
ax2 = plt.subplot(gs[0, 2:4])
ax3 = plt.subplot(gs[1, :2])
ax4 = plt.subplot(gs[1, 2:4])
ax5 = plt.subplot(gs[2, :2])
ax6 = plt.subplot(gs[2, 2:4])
axes = [ax1,ax2,ax3,ax4,ax5,ax6]
for i in range(0,len(ktypes_vals)):
    ax = axes[i]
    x_cdf, y_cdf = sorted(truth['Primary']), np.arange(len(truth['Primary'])) / len(truth['Primary'])
    ax.plot(x_cdf, y_cdf,label = ' Truth')
    est = ktypes_vals[i]
    x_cdf, y_cdf = sorted(est), np.arange(len(est)) / len(est)
    ax.plot(x_cdf, y_cdf, label = 'Estimate')
    ax.set_title('{}'.format(ktypes_vals_str[i]),size = 20)
    ax.set_xlabel('Grade',size = 20)
    ax.set_ylabel('CDF',size = 20)
    ax.legend(loc = 'best')
    ax.text(0.1,0.50,'Mean_True = {:.2f}'.format(mean[0]),size=10)
    ax.text(0.1,0.40,'Mean_Est = {:.2f}'.format(mean[i]),size=10)
    ax.text(0.1,0.30,'Var_True = {:.2f}'.format(var[0]),size=10)
    ax.text(0.1,0.20,'Var_Est = {:.2f}'.format(var[i]),size=10)
fig.savefig('../0-Figures/hist_rep_UB.png')
